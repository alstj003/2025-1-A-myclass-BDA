# %% [markdown]
# <a href="https://colab.research.google.com/github/alstj003/2025-1-A-myclass-BDA/blob/main/inclass/05w_A_mon_0407_easy_ch05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##05주 수업

# %% [markdown]
# ## 05-3 파생 변수 생성 p.116

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'var1': [4, 3, 8], 'var2': [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1.var1 + df1.var2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1.var_sum2 = df1.var1 + df1.var2
df1
# Out:
# <ipython-input-4-5b44662ff3f9>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.var_sum2 = df1.var1 + df1.var2
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1['var_mean'] = (df1.var1 + df1.var2) / 2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum()
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['my_sum'] = df2.sum(axis='columns')
df2
# Out:
#    var1  var2  my_sum
# 0     4     2       6
# 1     3     6       9
# 2     8     1       9

# %%
df2[["var1","var2"]]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2["my_mean"] = df2[["var1","var2"]].mean(axis=1)
df2
# Out:
#    var1  var2  my_sum  my_mean
# 0     4     2       6      3.0
# 1     3     6       9      4.5
# 2     8     1       9      4.5

# %% [markdown]
# ### mpg 통합 연비 변수 만들기

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.sample(8)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-880e6d206e32> in <cell line: 0>()
# ----> 1 mpg = pd.read_csv('data/mpg.csv')
#       2 mpg.sample(8)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
